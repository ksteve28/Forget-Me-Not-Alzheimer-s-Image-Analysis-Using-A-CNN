# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import PIL

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Device:', tpu.master())
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
except:
    strategy = tf.distribute.get_strategy()
print('Number of replicas:', strategy.num_replicas_in_sync)
    
print(tf.__version__)
# Out:
# Number of replicas: 1
# 2.3.1

# %%
# AUTOTUNE = tf.data.experimental.AUTOTUNE
# BATCH_SIZE = 32 * strategy.num_replicas_in_sync
# IMAGE_SIZE = [176, 208]
# EPOCHS = 10

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
image_size = [176, 208]
batch_size = 32
epoch = 10

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(
    '../Alzheimer_s Dataset/train/',
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=image_size,
    batch_size=batch_size,
)

val_data = tf.keras.preprocessing.image_dataset_from_directory(
    '../Alzheimer_s Dataset/train',
        validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=image_size,
    batch_size=batch_size,
)
# Out:
# Found 2612 files belonging to 2 classes.
# Using 2090 files for training.
# Found 2612 files belonging to 2 classes.
# Using 522 files for validation.

# %%
class_names = ['ModerateDementia', 'NonDementia']
train_data.class_names = class_names
val_data.class_names = class_names

NUM_CLASSES = len(class_names)

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_data.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(train_data.class_names[labels[i]])
    plt.axis("off")

# %%
def one_hot_label(image, label):
    label = tf.one_hot(label, NUM_CLASSES)
    return image, label

train_data = train_data.map(one_hot_label, num_parallel_calls=AUTOTUNE)
val_data = val_data.map(one_hot_label, num_parallel_calls=AUTOTUNE)

# %%
train_data = train_data.cache().prefetch(buffer_size=AUTOTUNE)
val_data = val_data.cache().prefetch(buffer_size=AUTOTUNE)

# %%
def conv_block(filters):
    block = tf.keras.Sequential([
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.SeparableConv2D(filters, 3, activation='relu', padding='same'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.MaxPool2D()
    ]
    )
    
    return block

# %%
def dense_block(units, dropout_rate):
    block = tf.keras.Sequential([
        tf.keras.layers.Dense(units, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dropout(dropout_rate)
    ])
    
    return block

# %%
def build_model():
    model = tf.keras.Sequential([
        tf.keras.Input(shape=(*image_size, 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
    ])
    
    return model

# %%
with strategy.scope():
    model = build_model()

    METRICS = [tf.keras.metrics.AUC(name='auc')]
    
    model.compile(
        optimizer='adam',
        loss=tf.losses.CategoricalCrossentropy(),
        metrics=METRICS
    )

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 20)

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("alzheimer_model.h5",
                                                    save_best_only=True)

early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,
                                                     restore_best_weights=True)

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
#     callbacks=[checkpoint_cb, early_stopping_cb, lr_scheduler],
    epochs=epoch
)
# Out:
# Epoch 1/10
# 66/66 [==============================] - 81s 1s/step - auc: 0.6538 - loss: 0.7903 - val_auc: 0.9751 - val_loss: 0.3313
# Epoch 2/10
# 66/66 [==============================] - 74s 1s/step - auc: 0.8819 - loss: 0.4379 - val_auc: 0.9751 - val_loss: 0.2268
# Epoch 3/10
# 66/66 [==============================] - 74s 1s/step - auc: 0.9635 - loss: 0.2782 - val_auc: 0.9751 - val_loss: 0.1287
# Epoch 4/10
# 66/66 [==============================] - 73s 1s/step - auc: 0.9837 - loss: 0.1786 - val_auc: 0.9751 - val_loss: 0.1181
# Epoch 5/10
# 66/66 [==============================] - 72s 1s/step - auc: 0.9872 - loss: 0.1425 - val_auc: 0.9751 - val_loss: 0.1472
# Epoch 6/10
# 66/66 [==============================] - 73s 1s/step - auc: 0.9879 - loss: 0.1126 - val_auc: 0.9751 - val_loss: 0.1658
# Epoch 7/10
# 66/66 [==============================] - 74s 1s/step - auc: 0.9864 - loss: 0.1099 - val_auc: 0.9749 - val_loss: 0.1370
# Epoch 8/10
# 66/66 [==============================] - 73s 1s/step - auc: 0.9877 - loss: 0.1024 - val_auc: 0.9751 - val_loss: 0.1717
# Epoch 9/10
# 66/66 [==============================] - 73s 1s/step - auc: 0.9938 - loss: 0.0839 - val_auc: 0.9751 - val_loss: 0.1642
# Epoch 10/10
# 66/66 [==============================] - 73s 1s/step - auc: 0.9938 - loss: 0.0812 - val_auc: 0.9750 - val_loss: 0.1661

# %%
acc = history.history['auc']
val_acc = history.history['val_auc']

loss = history.history['loss']
val_loss = history.history['val_auc']

epochs_range = range(epoch)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
# w_standarization = model.fit(
#     train_data,
#     validation_data=val_data,
# #     callbacks=[checkpoint_cb, early_stopping_cb, lr_scheduler],
#     epochs=epoch
# )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-7e1e6347c2fb> in <module>
# ----> 1 w_standarization = model.fit(
#       2     train_data,
#       3     validation_data=val_data,
#       4 #     callbacks=[checkpoint_cb, early_stopping_cb, lr_scheduler],
#       5     epochs=epoch
#
# AttributeError: 'NoneType' object has no attribute 'fit'

# %%
test_data = tf.keras.preprocessing.image_dataset_from_directory(
    '../Alzheimer_s Dataset/test/',
    image_size=image_size,
    batch_size=batch_size,
)
test_data = test_data.map(one_hot_label, num_parallel_calls=AUTOTUNE)
test_data = test_data.cache().prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 652 files belonging to 2 classes.

# %%
model.evaluate(test_data)
# Out:
# 21/21 [==============================] - 6s 274ms/step - auc: 0.5000 - loss: 0.6931
# [0.6931471228599548, 0.5]

# %%
def build_model_2():
    model = tf.keras.Sequential([
        tf.keras.layers.experimental.preprocessing.Rescaling(1./255),
        tf.keras.Input(shape=(*image_size, 3)),
        
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
        tf.keras.layers.MaxPool2D(),
        
        conv_block(32),
        conv_block(64),
        
        conv_block(128),
        tf.keras.layers.Dropout(0.2),
        
        conv_block(256),
        tf.keras.layers.Dropout(0.2),
        
        tf.keras.layers.Flatten(),
        dense_block(512, 0.7),
        dense_block(128, 0.5),
        dense_block(64, 0.3),
        
        tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
    ])
    
    return model

# %%
with strategy.scope():
    model = build_model_2()

    METRICS = [tf.keras.metrics.CategoricalAccuracy(name='categorical_accuracy')]
    
    model.compile(
        optimizer='adam',
        loss=tf.losses.CategoricalCrossentropy(),
        metrics=METRICS
    )

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 20)

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("alzheimer_model.h5",
                                                    save_best_only=True)

early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,
                                                     restore_best_weights=True)

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    callbacks=[checkpoint_cb, early_stopping_cb, lr_scheduler],
    epochs=epoch
)
# Out:
# Epoch 1/10
# 66/66 [==============================] - 97s 1s/step - categorical_accuracy: 0.9732 - loss: 0.1380 - val_categorical_accuracy: 0.9751 - val_loss: 0.1363
# Epoch 2/10
# 66/66 [==============================] - 108s 2s/step - categorical_accuracy: 0.9780 - loss: 0.1331 - val_categorical_accuracy: 0.9751 - val_loss: 0.4804
# Epoch 3/10
# 66/66 [==============================] - 112s 2s/step - categorical_accuracy: 0.9809 - loss: 0.1131 - val_categorical_accuracy: 0.9751 - val_loss: 5.5439
# Epoch 4/10
# 66/66 [==============================] - 112s 2s/step - categorical_accuracy: 0.9799 - loss: 0.0997 - val_categorical_accuracy: 0.9751 - val_loss: 1.5609
# Epoch 5/10
# 66/66 [==============================] - 103s 2s/step - categorical_accuracy: 0.9809 - loss: 0.0918 - val_categorical_accuracy: 0.9751 - val_loss: 0.8314
# Epoch 6/10
# 66/66 [==============================] - 105s 2s/step - categorical_accuracy: 0.9804 - loss: 0.0906 - val_categorical_accuracy: 0.9751 - val_loss: 1.3359
# Epoch 7/10
# 66/66 [==============================] - 114s 2s/step - categorical_accuracy: 0.9809 - loss: 0.0902 - val_categorical_accuracy: 0.9751 - val_loss: 0.1341
# Epoch 8/10
# 66/66 [==============================] - 123s 2s/step - categorical_accuracy: 0.9813 - loss: 0.0858 - val_categorical_accuracy: 0.9751 - val_loss: 0.1349
# Epoch 9/10
# 66/66 [==============================] - 88s 1s/step - categorical_accuracy: 0.9799 - loss: 0.0874 - val_categorical_accuracy: 0.9751 - val_loss: 0.5348
# Epoch 10/10
# 66/66 [==============================] - 85s 1s/step - categorical_accuracy: 0.9809 - loss: 0.0774 - val_categorical_accuracy: 0.9751 - val_loss: 0.1179

# %%
acc = history.history['categorical_accuracy']
val_acc = history.history['val_categorical_accuracy']

loss = history.history['loss']
val_loss = history.history['val_categorical_accuracy']

epochs_range = range(epoch)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
model.evaluate(test_data)
# Out:
# 21/21 [==============================] - 6s 308ms/step - categorical_accuracy: 0.9816 - loss: 0.0982
# [0.09819736331701279, 0.9815950989723206]

# %%
image_height = 178
image_width = 208
epoch = 10

# %%
# def build_model_2():
#     model = tf.keras.Sequential([
#         tf.keras.layers.experimental.preprocessing.Rescaling(1./255),
#         tf.keras.Input(shape=(*image_size, 3)),
        
#         tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
#         tf.keras.layers.Conv2D(16, 3, activation='relu', padding='same'),
#         tf.keras.layers.MaxPool2D(),
        
#         conv_block(32),
#         conv_block(64),
        
#         conv_block(128),
#         tf.keras.layers.Dropout(0.2),
        
#         conv_block(256),
#         tf.keras.layers.Dropout(0.2),
        
#         tf.keras.layers.Flatten(),
#         dense_block(512, 0.7),
#         dense_block(128, 0.5),
#         dense_block(64, 0.3),
        
#         tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')

#     return model

# %%
data_augmentation = tf.keras.Sequential(
  [
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal", 
                                                 input_shape=(image_height,
                                                              image_width,
                                                              3)),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.1),
    tf.keras.layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)
def model_two():
    model = tf.keras.Sequential([
        data_augmentation,
        tf.keras.layers.experimental.preprocessing.Rescaling(1./255),
        tf.keras.layers.Conv2D(16, 3, padding='same', activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
        tf.keras.layers.MaxPooling2D(),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128, activation='relu'),
        tf.keras.layers.Dense(NUM_CLASSES, activation='softmax')
])

# %%
with strategy.scope():
    model = model_two()

    METRICS = [tf.keras.metrics.AUC(name='auc')]
    
    model.compile(
        optimizer='adam',
        loss=tf.losses.CategoricalCrossentropy(),
        metrics=METRICS
    )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-dca0bc214d2c> in <module>
#       4     METRICS = [tf.keras.metrics.AUC(name='auc')]
#       5
# ----> 6     model.compile(
#       7         optimizer='adam',
#       8         loss=tf.losses.CategoricalCrossentropy(),
#
# AttributeError: 'NoneType' object has no attribute 'compile'

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(0.01, 20)

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("alzheimer_model.h5",
                                                    save_best_only=True)

early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,
                                                     restore_best_weights=True)

# %%
history = model.fit(
    train_data,
    validation_data=val_data,
    callbacks=[checkpoint_cb, early_stopping_cb, lr_scheduler],
    epochs=epoch
)
